# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../Data/process/Tube Mill.csv")
df.shape
# Out:
# /var/folders/q8/lvj6ms8d6g371mc9cl99f_6w0000gn/T/ipykernel_28853/679205554.py:4: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Data/process/Tube Mill.csv")
# (4504098, 11)

# %%
df.head()
# Out:
#                          id           Measurement        Date      Time  \
# 0  67c29bab30e6dd385f031c2c  Vibration Velocity Z  2025-04-15  22:05:05
# 1  67c29bab30e6dd385f031c2c  Vibration Velocity Z  2025-04-15  22:05:00
# 2  67c29bab30e6dd385f031c2c  Vibration Velocity Z  2025-04-15  22:04:55
# 3  67c29bab30e6dd385f031c2c  Vibration Velocity Z  2025-04-15  22:04:50
# 4  67c29bab30e6dd385f031c2c  Vibration Velocity Z  2025-04-15  22:04:45
#
#       data  unit     device             location Device Metric  Rating
# 0  2.86789  mm/s  Tube Mill  Motor Non-Drive End    NaN    NaN     NaN
# 1  2.70045  mm/s  Tube Mill  Motor Non-Drive End    NaN    NaN     NaN
# 2  2.62339  mm/s  Tube Mill  Motor Non-Drive End    NaN    NaN     NaN
# 3  2.71271  mm/s  Tube Mill  Motor Non-Drive End    NaN    NaN     NaN
# 4  2.91826  mm/s  Tube Mill  Motor Non-Drive End    NaN    NaN     NaN

# %%
df.tail()
# Out:
#                                id                   Measurement        Date  \
# 4504093  67c29bab30e6dd385f031c35  Low-Frequency Acceleration Z  2025-04-01
# 4504094  67c29bab30e6dd385f031c35  Low-Frequency Acceleration Z  2025-04-01
# 4504095  67c29bab30e6dd385f031c35  Low-Frequency Acceleration Z  2025-04-01
# 4504096  67c29bab30e6dd385f031c35  Low-Frequency Acceleration Z  2025-04-01
# 4504097  67c29bab30e6dd385f031c35  Low-Frequency Acceleration Z  2025-04-01
#
#              Time     data  unit     device         location Device Metric  \
# 4504093  00:00:20  2.00391  m/s2  Tube Mill  Motor Drive End    NaN    NaN
# 4504094  00:00:15  1.97935  m/s2  Tube Mill  Motor Drive End    NaN    NaN
# 4504095  00:00:10  2.03623  m/s2  Tube Mill  Motor Drive End    NaN    NaN
# 4504096  00:00:05  2.16396  m/s2  Tube Mill  Motor Drive End    NaN    NaN
# 4504097  00:00:00  2.14204  m/s2  Tube Mill  Motor Drive End    NaN    NaN
#
#          Rating
# 4504093     NaN
# 4504094     NaN
# 4504095     NaN
# 4504096     NaN
# 4504097     NaN

# %%
df.describe()
# Out:
#                data        Rating
# count  4.488048e+06  16050.000000
# mean   7.533242e+00     89.242799
# std    9.205158e+00      8.806731
# min    2.457000e-02     54.430000
# 25%    2.209560e+00     84.030000
# 50%    4.485290e+00     91.850000
# 75%    7.986030e+00     96.770000
# max    4.700000e+01     99.080000

# %%
df.isnull().sum()
# Out:
# id               16050
# Measurement      16050
# Date                 0
# Time                 0
# data             16050
# unit             16050
# device               0
# location             0
# Device         4488048
# Metric         4488048
# Rating         4488048
# dtype: int64

# %%
location_counts = df['location'].value_counts()

plt.figure(figsize=(10, 6))
location_counts.plot(kind='bar')

plt.title('Count of Rows by Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
unique_metrics = df['Metric'].unique()
print("Unique Metrics:")
print(unique_metrics)

unique_measurements = df['Measurement'].unique()
print("\nUnique Measurements:")
print(unique_measurements)
# Out:
# Unique Metrics:
# [nan 'velocity_rms' 'crest_factor' 'kurtosis_opt' 'rms_1_10khz'
#  'rms_10_25khz' 'peak_value_opt' 'rms_0_10hz' 'rms_10_100hz'
#  'peak_10_1000hz' 'rotor_balance_status' 'alignment_status'
#  'fit_condition' 'bearing_lubrication' 'rubbing_condition'
#  'electromagnetic_status']
#
# Unique Measurements:
# ['Vibration Velocity Z' 'High-Frequency Acceleration' 'Temperature'
#  'Low-Frequency Acceleration Z' nan]

# %%
pivot_df = df.copy().drop(columns=['Device','Metric','Rating']).dropna()
pivot_df = pivot_df.pivot_table(
    index=['id', 'Date', 'Time', 'device', 'location'],
    columns='Measurement',
    values='data'
)
pivot_df = pivot_df.reset_index()

pivot_df.head()
# Out:
# Measurement                        id        Date      Time     device  \
# 0            67c29bab30e6dd385f031c2c  2025-04-01  00:00:00  Tube Mill
# 1            67c29bab30e6dd385f031c2c  2025-04-01  00:00:05  Tube Mill
# 2            67c29bab30e6dd385f031c2c  2025-04-01  00:00:10  Tube Mill
# 3            67c29bab30e6dd385f031c2c  2025-04-01  00:00:15  Tube Mill
# 4            67c29bab30e6dd385f031c2c  2025-04-01  00:00:20  Tube Mill
#
# Measurement             location  High-Frequency Acceleration  \
# 0            Motor Non-Drive End                      5.70349
# 1            Motor Non-Drive End                      5.62642
# 2            Motor Non-Drive End                      5.58053
# 3            Motor Non-Drive End                      5.66389
# 4            Motor Non-Drive End                      5.75040
#
# Measurement  Low-Frequency Acceleration Z  Temperature  Vibration Velocity Z
# 0                                 2.52273         15.0               2.57589
# 1                                 2.56984          NaN               2.57818
# 2                                 2.41570         15.0               2.65499
# 3                                 2.48552          NaN               2.27237
# 4                                 2.54122         15.0               2.54896

# %%
target_df = df.copy().drop(columns=['id', 'Measurement', 'data','unit','device']).dropna()
target_df = target_df.pivot_table(
    index=['Date', 'Time', 'location', 'Device'],
    columns='Metric',
    values='Rating'
)
target_df = target_df.reset_index()
target_df.head()
# Out:
# Metric        Date      Time location     Device  alignment_status  \
# 0       2025-04-01  00:00:01   Rating  Tube Mill              98.0
# 1       2025-04-01  00:20:00   Rating  Tube Mill              93.4
# 2       2025-04-01  00:40:00   Rating  Tube Mill              93.4
# 3       2025-04-01  01:00:01   Rating  Tube Mill              93.4
# 4       2025-04-01  01:20:00   Rating  Tube Mill              93.4
#
# Metric  bearing_lubrication  crest_factor  electromagnetic_status  \
# 0                     93.30         91.38                    98.0
# 1                     94.33         90.35                    98.0
# 2                     94.33         90.35                    98.0
# 3                     94.33         90.35                    98.0
# 4                     94.33         90.35                    98.0
#
# Metric  fit_condition  kurtosis_opt  peak_10_1000hz  peak_value_opt  \
# 0               90.16         84.61           86.10           89.42
# 1               84.62         75.20           75.57           82.21
# 2               84.62         75.20           75.57           82.21
# 3               84.62         75.20           75.57           82.21
# 4               84.62         75.20           75.57           82.21
#
# Metric  rms_0_10hz  rms_10_100hz  rms_10_25khz  rms_1_10khz  \
# 0            92.79         76.13         96.91        93.44
# 1            96.29         74.98         96.66        93.82
# 2            96.29         74.98         96.66        93.82
# 3            96.29         74.98         96.66        93.82
# 4            96.29         74.98         96.66        93.82
#
# Metric  rotor_balance_status  rubbing_condition  velocity_rms
# 0                      97.44              96.23         78.31
# 1                      95.54              94.28         66.26
# 2                      95.54              94.28         66.26
# 3                      95.54              94.28         66.26
# 4                      95.54              94.28         66.26

# %%
pivot_df.to_csv("../Data/process/tube_mill_feature.csv", index=False)

# %%
pivot_df.to_csv("../Data/process/tube_mill_target.csv", index=False)
