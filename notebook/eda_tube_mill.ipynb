# %%
import sys
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(PROJECT_ROOT)

from model.utils import (
    load_and_clean_data,
    show_summary,
    plot_feature_distributions,
    plot_feature_correlation_heatmap,
    plot_feature_boxplots,
    plot_target_distributions,
    plot_target_boxplots,
    get_device_name,
    DEVICE_TARGET_FEATURES,
    INPUT_FEATURES
)
DEVICE = "tube_mill"
TARGET_FEATURES = DEVICE_TARGET_FEATURES[DEVICE]
DATA_DIR = "../Data/process/Tube Mill_merged.csv"
SAVE_PATH = f"../docs/images/{DEVICE}_plots/"

# %%
df = load_and_clean_data(DATA_DIR)

# %%
show_summary(df)
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1278845 entries, 0 to 1280554
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   datetime                      1278845 non-null  object
#  1   location                      1278845 non-null  object
#  2   High-Frequency Acceleration   1278845 non-null  float64
#  3   Low-Frequency Acceleration Z  1278845 non-null  float64
#  4   Temperature                   1278845 non-null  float64
#  5   Vibration Velocity Z          1278845 non-null  float64
#  6   Device                        1278845 non-null  object
#  7   alignment_status              1278845 non-null  float64
#  8   bearing_lubrication           1278845 non-null  float64
#  9   crest_factor                  1278845 non-null  float64
#  10  electromagnetic_status        1278845 non-null  float64
#  11  fit_condition                 1278845 non-null  float64
#  12  kurtosis_opt                  1278845 non-null  float64
#  13  peak_10_1000hz                1278845 non-null  float64
#  14  peak_value_opt                1278845 non-null  float64
#  15  rms_0_10hz                    1278845 non-null  float64
#  16  rms_10_100hz                  1278845 non-null  float64
#  17  rms_10_25khz                  1278845 non-null  float64
#  18  rms_1_10khz                   1278845 non-null  float64
#  19  rotor_balance_status          1278845 non-null  float64
#  20  rubbing_condition             1278845 non-null  float64
#  21  velocity_rms                  1278845 non-null  float64
# dtypes: float64(19), object(3)
# memory usage: 224.4+ MB
# None
#
# Statistical Summary:
#        High-Frequency Acceleration  Low-Frequency Acceleration Z  \
# count                 1.278845e+06                  1.278845e+06
# mean                  4.339303e+00                  3.421610e+00
# std                   2.755533e+00                  2.813046e+00
# min                   1.914100e-01                  2.457000e-02
# 25%                   2.232300e-01                  5.427000e-02
# 50%                   4.495540e+00                  2.634680e+00
# 75%                   6.423640e+00                  6.255410e+00
# max                   1.788689e+01                  1.540522e+01
#
#         Temperature  Vibration Velocity Z  alignment_status  \
# count  1.278845e+06          1.278845e+06      1.278845e+06
# mean   2.790600e+01          4.625960e+00      9.299042e+01
# std    6.709146e+00          3.888294e+00      2.031110e+00
# min    4.600000e+00          4.775000e-02      8.780000e+01
# 25%    2.340000e+01          1.210400e-01      9.148000e+01
# 50%    2.840000e+01          3.114610e+00      9.292000e+01
# 75%    3.250000e+01          8.069320e+00      9.419000e+01
# max    4.700000e+01          3.983741e+01      9.800000e+01
#
#        bearing_lubrication  crest_factor  electromagnetic_status  \
# count         1.278845e+06  1.278845e+06            1.278845e+06
# mean          9.319756e+01  9.090659e+01            9.799962e+01
# std           1.026521e+00  3.685807e-01            8.233801e-03
# min           8.887000e+01  8.961000e+01            9.781000e+01
# 25%           9.295000e+01  9.065000e+01            9.800000e+01
# 50%           9.350000e+01  9.095000e+01            9.800000e+01
# 75%           9.382000e+01  9.116000e+01            9.800000e+01
# max           9.471000e+01  9.175000e+01            9.800000e+01
#
#        fit_condition  kurtosis_opt  peak_10_1000hz  peak_value_opt  \
# count   1.278845e+06  1.278845e+06    1.278845e+06    1.278845e+06
# mean    8.714432e+01  8.297644e+01    8.091094e+01    8.457960e+01
# std     2.798516e+00  3.019007e+00    5.382375e+00    5.603191e+00
# min     7.986000e+01  7.500000e+01    5.841000e+01    5.443000e+01
# 25%     8.559000e+01  8.124000e+01    7.868000e+01    8.126000e+01
# 50%     8.806000e+01  8.397000e+01    8.249000e+01    8.623000e+01
# 75%     8.916000e+01  8.514000e+01    8.461000e+01    8.883000e+01
# max     9.202000e+01  8.737000e+01    8.831000e+01    9.164000e+01
#
#          rms_0_10hz  rms_10_100hz  rms_10_25khz   rms_1_10khz  \
# count  1.278845e+06  1.278845e+06  1.278845e+06  1.278845e+06
# mean   9.736580e+01  7.340554e+01  9.673207e+01  9.347142e+01
# std    2.472504e+00  4.547363e+00  2.001274e-01  4.511170e-01
# min    7.075000e+01  6.145000e+01  9.621000e+01  9.167000e+01
# 25%    9.800000e+01  7.000000e+01  9.661000e+01  9.326000e+01
# 50%    9.800000e+01  7.408000e+01  9.672000e+01  9.361000e+01
# 75%    9.800000e+01  7.705000e+01  9.686000e+01  9.380000e+01
# max    9.800000e+01  8.543000e+01  9.800000e+01  9.433000e+01
#
#        rotor_balance_status  rubbing_condition  velocity_rms
# count          1.278845e+06       1.278845e+06  1.278845e+06
# mean           9.699472e+01       9.713616e+01  7.276283e+01
# std            9.375234e-01       2.133520e+00  4.538108e+00
# min            9.459000e+01       8.956000e+01  6.093000e+01
# 25%            9.660000e+01       9.564000e+01  7.019000e+01
# 50%            9.746000e+01       9.834000e+01  7.420000e+01
# 75%            9.763000e+01       9.863000e+01  7.607000e+01
# max            9.800000e+01       9.908000e+01  7.917000e+01
#
# Missing Values:
# datetime                        0
# location                        0
# High-Frequency Acceleration     0
# Low-Frequency Acceleration Z    0
# Temperature                     0
# Vibration Velocity Z            0
# Device                          0
# alignment_status                0
# bearing_lubrication             0
# crest_factor                    0
# electromagnetic_status          0
# fit_condition                   0
# kurtosis_opt                    0
# peak_10_1000hz                  0
# peak_value_opt                  0
# rms_0_10hz                      0
# rms_10_100hz                    0
# rms_10_25khz                    0
# rms_1_10khz                     0
# rotor_balance_status            0
# rubbing_condition               0
# velocity_rms                    0
# dtype: int64

# %%
plot_feature_distributions(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE HISTOGRAM DISTRIBUTION", save_path=SAVE_PATH)

# %%
plot_feature_distributions(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE HISTOGRAM DISTRIBUTION (OUTLIERS REMOVED)", remove_outliers=True, save_path=SAVE_PATH)

# %%
plot_feature_correlation_heatmap(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE CORRELATION HEATMAP", save_path=SAVE_PATH)

# %%
plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS", save_path=SAVE_PATH)

# %%
plot_feature_boxplots(df, INPUT_FEATURES, f"{get_device_name(DEVICE)} - FEATURE BOXPLOTS DISTRIBUTIONS (OUTLIERS REMOVED)", remove_outliers=True,  save_path=SAVE_PATH)

# %%
plot_target_distributions(df, TARGET_FEATURES, f"{get_device_name(DEVICE)} - TARGET HISTOGRAM DISTRIBUTIONS",save_path=SAVE_PATH)

# %%
plot_target_boxplots(df, TARGET_FEATURES, f"{get_device_name(DEVICE)} - TARGET BOXPLOTS DISTRIBUTIIONS", save_path=SAVE_PATH)
